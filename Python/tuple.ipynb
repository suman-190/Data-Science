# %%
# t1 =  (2,3,5,6,7,8)
# t2=(10) 

# this is int type
# indexing and slicing
# tuple is immutable
# 
# 


# t2 = (10,)
# print(type(t2))

# t3 = 1,2,4,5,6
# int_t1 = 23,
# print(type(t3))
# print(type(int_t1))
# print(t3[1])


mul_tup = ((23,34),(23,45))
mul_arr = [[23,34],[23,45]]

print(mul_tup[0][1])
print(mul_arr[0][1])
# Out:
# 34
# 34

# %%
dic4 = dict([("name","Suman"),("age","23")])
person = {
    "name":"Sagar"
}
dic4['degree']="B.E"

# print(dic4)
# len(dic4)
# max(dic4)
# sorted(dic4)
# sorted(dic4,reverse=True)
print(person.items())
print(person.keys())
print(person.values())

# list = [i for i in range(4)]
# list
# Out:
# dict_items([('name', 'Sagar')])
# dict_keys(['name'])
# dict_values(['Sagar'])

# %%
fruits = {"apple", "banana", "cherry", "apple"}
print(fruits)
# Out:
# {'apple', 'cherry', 'banana'}

# %%
A = {1, 2, 3, 4}
B = {3, 4, 5, 6}

print(A | B)

print(A.union(B))
print(A.intersection(B))
print(A.difference(B))
print(B.difference(A))
# Out:
# {1, 2, 3, 4, 5, 6}
# {1, 2, 3, 4, 5, 6}
# {3, 4}
# {1, 2}
# {5, 6}

# %%
my_set = {"apple", "banana", "cherry"}

for fruit in my_set:
    print(fruit,end="")


my_list=list(my_set)

print(my_set)
# Out:
# applecherrybanana
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[51], line 7
#       3 for fruit in my_set:
#       4     print(fruit,end="")
# ----> 7 my_list=list(my_set)
#       9 print(my_set)
#
# TypeError: 'list' object is not callable
