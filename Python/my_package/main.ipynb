# %%
# import my_package.count_element.count as count

# count.count_element(["Name"])
# Out:
# 1

# %%
from count_element import count


count.count_list("Suman")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 4
#       1 from count_element import count
# ----> 4 count.count_list("Suman")
#
# AttributeError: module 'count_element.count' has no attribute 'count_list'
