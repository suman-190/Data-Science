# %% [markdown]
# # while loop is used to conditionally repeat a block of code

# %%
l1 = ["lalitpur","kathmandu"]
# mutable,
l1[-1]="Bhaktpur"
print(l1)
l1.append("Dang")
l1.append(23)
del l1[1]
print(l1)



# attributes
# Out:
# ['lalitpur', 'Bhaktpur']
# ['lalitpur', 'Dang', 23]

# %%
l1= ["Thor","Loki","IronMan"]
l1.insert(2,"Hulk")
l1
# Out:
# ['Thor', 'Loki', 'Hulk', 'IronMan']

# %%
a=int(input())
b=int(input())
L=a if a>b else b
while(L<=a*b):
    if(L%a==0 and L%b==0):
        print("LCM is",L)
        break
    L+=1

# %%
li1= [2,3,4,5]
li2 = [56,65,78,3]
print(li1+li2)
a=23
b=43

result_list = [li1,li2,a,b]

print("Result List",result_list)

print([1,2]*4)
print(f"suman {li1}"*3)
# Out:
# [2, 3, 4, 5, 56, 65, 78, 3]
# Result List [[2, 3, 4, 5], [56, 65, 78, 3], 23, 43]
# [1, 2, 1, 2, 1, 2, 1, 2]
# suman [2, 3, 4, 5]suman [2, 3, 4, 5]suman [2, 3, 4, 5]

# %%
num_list = [6,2,4,5,5]
# num_list.reverse()
# print(num_list.remove(5))
# print(num_list.pop()) 
# pop return the value

print(num_list)
print(num_list.index(5)) 
# return index
print("Count",num_list.count(5))

sorted_num = sorted(num_list)
print("Sorted",sorted_num)
# Out:
# [6, 2, 4, 5, 5]
# 3
# Count 2
# Sorted [2, 4, 5, 5, 6]

# %%
name = "Suman"
a= "s" in name
print(a)
# Out:
# False

# %%
arr = [a+2 for a in range(5)]
print(arr)
# Out:
# [2, 3, 4, 5, 6]

# %%
name_list = ["suman","Sophiya","Kamal","Stephen"]
print(sorted(name_list[0]))
name="Suman"

print(name)
# Out:
# ['a', 'm', 'n', 's', 'u']
# Suman

# %%
name = "Suman"
print(name)
print(name)
print(name)
min(name)
# Out:
# Suman
# Suman
# Suman
# 'S'

# %%
num=[2,5,6,8,2,0]
print(num[::-1])
print(num[1:3:2])
# Out:
# [0, 2, 8, 6, 5, 2]
# [5]

# %% [markdown]
# #### List is a class
# #### List is an iterable sequence
# #### List is Mutable
# #### List is Growable
# #### List Can Store Heterogeneous data
# #### List Element are indexed

# %%
l1 = [10,12,43]
l1.insert(-2,20)
print(l1)
# Out:
# [10, 20, 12, 43]

# %%
# Packing and Unpacking
l1 = [20,40,60]

a,b,c=l1

x=20
y=30
z=40

l2= [x,y,z]

# numbers of variable in the left hand side must be same as the numbers of elements in the list

print(a)
print(b)
print(c)

print(l2)
# Out:
# 20
# 40
# 60
# [20, 30, 40]

# %%
# Built In Methods

l1 = [22,30,10,12,43,50,100,200]

print(len(l1))
print(min(l1))
print(max(l1))
print(sorted(l1))
print(sum(l1))



for i in range(-1,-5):
    print(i)
# Out:
# 8
# 10
# 200
# [10, 12, 22, 30, 43, 50, 100, 200]
# 467

# %%
li1 = list(20)
print(li1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 li1 = list(20)
#       2 print(li1)
#
# TypeError: 'int' object is not iterable

# %%
# We can pass Iterable sequence inside list function
l=list(20) 
# Error 
li1 = list("Suman")
li1 = list(range(1,34,10))

print(li1)
# Out:
# [1, 11, 21, 31]

# %%
# comparison Operator on List

l1 = [2,2,3,4]
l2 = [2,3,1]
l3 = [1,2,3,4,5]
l4 = [1,2,3,4]
print(l1 == l4)
print(l1 > l4)
print(l1 == l2)
# Out:
# False
# True
# False

# %%
l1 = [2,2,3,4]
l2 = [2,3,1]

print(l1+l2)

# Repeatation Operator

print(l2 * 3)
# Out:
# [2, 2, 3, 4, 2, 3, 1]
# [2, 3, 1, 2, 3, 1, 2, 3, 1]

# %%
l1 = [22,30,10,12,12,43,50,100,200]

l1.append(20)
l1.remove(100)
# It will remove fist Occurance of Element

print(l1.pop())
# It will return the value

# l1.clear()
# It will remove all the list




print(l1.index(12))
# It will return the Index
print(l1.count(12))
#  Count the occurance 

print(sorted(l1,reverse=True))

l1.sort()
print(l1)
# Out:
# 20
# 3
# 2
# [200, 50, 43, 30, 22, 12, 12, 10]
# [22, 30, 10, 12, 12, 43, 50, 200]

# %%
# List Comprehension

# [expression for variable in iterable]
# python is know for Precise coding style


lc = [e**2 for e in range(5)]
print(lc)

lc1 = [3+3 for e in range(5)]
print(lc1)

# Create a list of first n odd natural number

oddNum  =  [e*2-1 for e in  range(1,int(input("Enter a number"))+1)]
print(oddNum)
# Out:
# [0, 1, 4, 9, 16]
# [6, 6, 6, 6, 6]
# [1, 3, 5, 7, 9]
