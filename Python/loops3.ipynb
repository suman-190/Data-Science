# %%
print("Hello")
# formatted string literal
number = int(input("Enter a number"))

i=1
while i<=10:
    print(f"{number} * {i}  = {number*i}")
    i=i+1
# Out:
# Hello
# 6 * 1  = 6
# 6 * 2  = 12
# 6 * 3  = 18
# 6 * 4  = 24
# 6 * 5  = 30
# 6 * 6  = 36
# 6 * 7  = 42
# 6 * 8  = 48
# 6 * 9  = 54
# 6 * 10  = 60
