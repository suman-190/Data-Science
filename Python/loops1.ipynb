# %%
i=0
while i<5:
    print("Hello")
    i=i+1
# Out:
# Hello
# Hello
# Hello
# Hello
# Hello

# %%
# Program to Print First N natural number
# continue
# break
n = int(input("Enter a Number"))
i=1
while i<=n:
    print(i ,n, sep=" ")
    # continue
    i=i+1
# Out:
# 110
# 210
# 310
# 410
# 510
# 610
# 710
# 810
# 910
# 1010

# %%
#Write a program to calculate first n natural number
# Prime Number
n=4
i = 2
while i<n:
    if(n%i==0):
        print("Number is Not Prime")
        break
    i=i+1     
if(n==i):
    print("Prime")
# Out:
# Number is Not Prime

# %%
# for varible in iterable_squence

# While repeats code Conditionally
# for iterated n time 

for i in "Suman Bhandari":
    print(i)
# Out:
# S
# u
# m
# a
# n
#
# B
# h
# a
# n
# d
# a
# r
# i
