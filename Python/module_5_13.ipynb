# %%
# Module and Packages

#mdoule is a single python file it can include functions, classes, variables that you can use in other programms 

import math

math.sqrt(16)
# Out:
# 4.0

# %%
from math import sqrt,pi
import numpy as np

np.array([1,2,3,4,5])

# %%
from math import *

from calculator.math import addition




print(math.addition(2,4))
print(sqrt(16))
print(pi)
# Out:
# 6
# 4.0
# 3.141592653589793

# %%
import random


print(random.randint(1,2))
print(random.choice(["Cherry","Banana","apple"]))
# Out:
# 2
# Banana

# %%
from my_package.count_element import count 





print(count.count_element(["Thar", "Car", "Bus"]))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 from my_package import count
#       7 print(count.count_element(["Thar", "Car", "Bus"]))
#
# File d:\Data-Science\Python\my_package\__init__.py:5
#       2 from my_package.model import count
# ----> 5 count([2,3,4,5,6])
#
# TypeError: 'module' object is not callable
