# %%
for i in range(1,10):
    if i ==5:
        break
    print(i)
# Out:
# 1
# 2
# 3
# 4

# %%
for i in range(1,10):
    if i ==5:
        continue
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 6
# 7
# 8
# 9

# %%
for i in range(1,10):
    pass

# %%
# In python Specifically, strings are a sequence of UniCode Character

s= 'Hello'
s1 = "Hello"
s2= '''hello'''
print(s2)
# Out:
# hello

# %%
# Indexing

s1 = 'DataBaseManagementSystem'

print(s1[-3])

# Slicing

print(s1[0:5:2])
# Out:
# t
# DataB
