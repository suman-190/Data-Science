# %%
import numpy as np
data = {i : np.random.randn() for i in range(7)}
data
# Out:
# {0: 1.4611392435530202,
#  1: -0.20022851545571818,
#  2: -0.45718465555964577,
#  3: 1.9273862410440503,
#  4: -0.050653075380952824,
#  5: 1.0167414795622214,
#  6: 1.0887191096099071}
