# %%
# Naming and Using Variables

''' 
message_1 but not 1_message
greeting_message works, but greeting message will cause errors.
Avoid using Python keywords and function names as variable names; 

Variable names should be short but descriptive. For example, name is
better than n, student_name is better than s_n, and name_length is better
than length_of_persons_name
'''

s1 = "this is for lower and upper"



print(s1.title())

print(s1.upper())

print(s1.lower())


print(s1)
# Out:
# This Is For Lower And Upper
# THIS IS FOR LOWER AND UPPER
# this is for lower and upper
# this is for lower and upper

# %%
str1= "GlobalIOT"
print(len(str1))

i = str1.index('I')

print(i)
print(str1.startswith('Gl'))
print(str1.endswith('OT'))


s2  = 'a12'
s3  = '12'
print(s2.isdigit())
# all letter must be digit if so it will show True otherwise False
print(s3.isdigit())

print(s2.islower())

s2 = "hello"
print(s2.islower())  # True

s2 = "Hello"
print(s2.islower())  # False

s2 = "123"
print(s2.islower())  # False

s2 = "hello123"
print(s2.islower()) # True  ✅ (non-letters ignored)
# Out:
# 9
# 6
# True
# True
# False
# True
# True

# %%
s = "HELLO"
print(s.isupper())  # ✅ True

s = "Hello"
print(s.isupper())  # ❌ False (because of lowercase "e", "l", "l", "o")

s = "HELLO123"
print(s.isupper())  # ✅ True (digits are ignored)

s = "123"
print(s.isupper())  # ❌ False (no letters at all)

s = ""
print(s.isupper())  # ❌ False (empty string)

# %%
s1 = "dataScience"

print(s1.upper())
help(str.upper)
# Out:
# DATASCIENCE
# Help on method_descriptor:
#
# upper(self, /) unbound builtins.str method
#     Return a copy of the string converted to uppercase.

# %%
s1 = "dataScience"
print(s1.replace("d","D"))
print(s1.replace("a","A"))
# Fisrt Occ
# Out:
# DataScience
# dAtAScience

# %%
# 

import random
guess_number = int(input("Guess the number: "))
correct_number = random.randint(1,50)
gurss_count = 0
while guess_number != correct_number:
    print("wrong guess")
    if guess_number > correct_number and guess_number < 51:
        print("too high")
        guess_number = int(input("Guess the number: "))
        gurss_count += 1
    elif guess_number < correct_number and guess_number > 0:
        print("too low")
        guess_number = int(input("Guess the number: "))

        gurss_count += 1

    elif guess_number > correct_number:
        print("out of bound")
        guess_number = int(input("Guess the number: "))


if guess_number == correct_number:
    print("correct")
    gurss_count += 1
print("total guess count: ",gurss_count)
# Out:
# wrong guess
# too high
# wrong guess
# too high
# wrong guess
# too high
# wrong guess
# too high
# wrong guess
# too high
# wrong guess
# too high
# wrong guess
# too high
# wrong guess
# too high
# wrong guess
# too high
# wrong guess
# too high
# wrong guess
# too high
# wrong guess
# too high
# wrong guess
# too high
# wrong guess
# too high
# wrong guess
# too high
# wrong guess
# too high
# wrong guess
# too high
# wrong guess
# too high
# wrong guess
# too high
# wrong guess
# too high
# wrong guess
# too high
# wrong guess
# too high
# wrong guess
# too high
# wrong guess
# too high
# wrong guess
# too high
# wrong guess
# too high
# wrong guess
# too high
# wrong guess
# too high
# wrong guess
# too high
# wrong guess
# too high
# wrong guess
# too high
# wrong guess
# too high
# wrong guess
# too high
# wrong guess
# too high
# wrong guess
# too high
# wrong guess
# too high
# wrong guess
# too high
# wrong guess
# too high
# wrong guess
# too high
# wrong guess
# too high
# ...

# %%
s1 = "GlobaIoT"

print(len(s1))
print(s1.count("o"))
print(s1.index("o"))
# 
print(s1.startswith("Gl"))
print(s1.endswith("IOT"))


s2 = 'a12'

print(s2.isdigit())

# non-letter ignored

s3 = "hello123"

print(s3.islower())
# Out:
# 8
# 2
# 2
# True
# False
# False
# True

# %%
s4 = ""

print(s4.isupper())
# Out:
# False

# %%
str1= "dataScience"

a = str1.upper()
print(a)

help(str.upper)

print(str1.replace("a","A"))


print(str1)
# Out:
# DATASCIENCE
# Help on method_descriptor:
#
# upper(self, /) unbound builtins.str method
#     Return a copy of the string converted to uppercase.
#
# dAtAScience
# dataScience
