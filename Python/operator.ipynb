# %%
# Logical Operator

print(1 and 1)
print(1 & 1)

print(1 or 1)
print(1 | 1)

print(not 1)
print(~ 1)

# XOR = If Both value is same 0

print (2 ^ 3)
# 10 11
# Out:
# 1
# 1
# 1
# 1
# False
# -2
# 1

# %%
# Assignment
a= 2
a+=2
print(a)
# Out:
# 4

# %%
# MemberShip Operator

print('D' in 'Data' )
print('a' not in 'Data' )
print()
# Out:
# True
# False

# %%
# Take a three digit  number  and Sum of them

# %%
num = 10

print(num==10)
# Out:
# True

# %%
a= 1
b=0
result = 1 and 0
result1 = 1 and 1
res2 = a or b
print(result)
print(result1)
print(res2)

print(not 0)

print( a and not b)


print(2 | 3)
# Out:
# 0
# 1
# 1
# True
# True
# 3

# %%
# Take 3 digit number from user 345 = 12

# num = int(input("Enter a number"))


print(type(num))


print(5/2)
print(5//2)
# Out:
# <class 'int'>
# 2.5
# 2

# %%
# 234

# a= 234
# res1 =a%10
# a=a//10

#
