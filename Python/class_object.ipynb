# %%
print("Hello")
# Out:
# Hello

# %%
l=[]

str = "suman"

# %%
class Atm:
    # It is special function => No need to call contructor function
    def __init__(self):
        self.pin=''
        self.balance=0
        print("Hello")
    def menu(self):
        userInput = input("Enter a Number")
        print(userInput)



a1 = Atm()

a1.menu()
# Out:
# Hello
# sjs
