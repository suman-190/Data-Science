# %%
for i in range(1,10):
    if i ==5:
        break
    print(i)
# Out:
# 1
# 2
# 3
# 4

# %%
for i in range(1,10):
    if i ==5:
        continue
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 6
# 7
# 8
# 9

# %%
for i in range(1,10):
    pass

# %%
# In python Specifically, strings are a sequence of UniCode Character

s= 'Hello'
s1 = "Hello"
s2= '''hello'''
print(s2)
# Out:
# hello

# %%
# Indexing

s1 = 'DataBaseManagementSystem'

print(s1[-3])

# Slicing

print(s1[1:])
print(s1[:4])
print(s1[0:5])
print(s1[0:10:2])
# Out:
# t
# ataBaseManagementSystem
# Data
# DataB
# DtBsM

# %%
s= "GlobalIOT"
del s[1]
print(s)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 3
#       1 s= "GlobalIOT"
# ----> 3 del s[1]
#       4 print(s)
#
# TypeError: 'str' object doesn't support item deletion

# %%
print('Global'+'IOT')
print("Glibal"*5)
# Out:
# GlobalIOT
# GlibalGlibalGlibalGlibalGlibal
