# %% [markdown]
# # while loop is used to conditionally repeat a block of code

# %%
l1 = ["lalitpur","kathmandu"]
# mutable,
l1[-1]="Bhaktpur"
print(l1)
l1.append("Dang")
l1.append(23)
del l1[1]
print(l1)



# attributes
# Out:
# ['lalitpur', 'Bhaktpur']
# ['lalitpur', 'Dang', 23]

# %%
l1= ["Thor","Loki","IronMan"]
l1.insert(2,"Hulk")
l1
# Out:
# ['Thor', 'Loki', 'Hulk', 'IronMan']

# %%
a=int(input())
b=int(input())
L=a if a>b else b
while(L<=a*b):
    if(L%a==0 and L%b==0):
        print("LCM is",L)
        break
    L+=1
# Out:
# LCM is 506

# %%
li1= [2,3,4,5]
li2 = [56,65,78,3]
print(li1+li2)
a=23
b=43

result_list = [li1,li2,a,b]

print("Result List",result_list)

print([1,2]*4)
print(f"suman {li1}"*3)
# Out:
# [2, 3, 4, 5, 56, 65, 78, 3]
# Result List [[2, 3, 4, 5], [56, 65, 78, 3], 23, 43]
# [1, 2, 1, 2, 1, 2, 1, 2]
# suman [2, 3, 4, 5]suman [2, 3, 4, 5]suman [2, 3, 4, 5]

# %%
num_list = [6,2,4,5,5]
# num_list.reverse()
# print(num_list.remove(5))
# print(num_list.pop()) 
# pop return the value

print(num_list)
print(num_list.index(5)) 
# return index
print("Count",num_list.count(5))

sorted_num = sorted(num_list)
print("Sorted",sorted_num)
# Out:
# [6, 2, 4, 5, 5]
# 3
# Count 2
# Sorted [2, 4, 5, 5, 6]

# %%
name = "Suman"
a= "s" in name
print(a)
# Out:
# False

# %%
arr = [a+2 for a in range(5)]
print(arr)
# Out:
# [2, 3, 4, 5, 6]

# %%
name_list = ["suman","Sophiya","Kamal","Stephen"]
print(sorted(name_list[0]))
name="Suman"

print(name)
# Out:
# ['a', 'm', 'n', 's', 'u']
# Suman

# %%
name = "Suman"
print(name)
print(name)
print(name)
min(name)
# Out:
# Suman
# Suman
# Suman
# 'S'

# %%
num=[2,5,6,8,2,0]
print(num[::-1])
print(num[1:3:2])
# Out:
# [0, 2, 8, 6, 5, 2]
# [5]
