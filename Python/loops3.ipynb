# %%
# print("Hello")
# formatted string literal
# The f in print(f"...") stands for "formatted string literal" or f-string, which was introduced in Python 3.6.

# It allows you to embed expressions inside string literals using curly braces {}. These expressions are evaluated at runtime and then formatted using the result.




number = int(input("Enter a number"))

i=1
while i<=10:
    print(f"{number} * {i}  = {number*i}")    
    i=i+1
# Out:
# 44 * 1  = 44
# 44 * 2  = 88
# 44 * 3  = 132
# 44 * 4  = 176
# 44 * 5  = 220
# 44 * 6  = 264
# 44 * 7  = 308
# 44 * 8  = 352
# 44 * 9  = 396
# 44 * 10  = 440

# %%
# while 5:
#     print("Suman Bhandari")
#     # break


# while 5:
#     print("Suman Bhandari")
#     break


# write a program to print first N natural Number


n = int(input("enter a number"))
i=1
while i<n:
    print(i,end=" ")
    i=i+2
# Out:
# 1234

# %%
# write a program

# %%
# break is used to transfer control outside the loop
# break terminates the execution of the loop

# %%
# for -variable- in -iterable_sequence-:
# code
# code 
# -iterable_sequence => List, tuple, str, range
# While is used to conditionally reapeat a block of code=
# for iterates n times, where n is the number of elements in a sequence

t1 = (5,2,4,5,6)
for i in t1:
    print(i)
# Out:
# 5
# 2
# 4
# 5
# 6

# %%
print(ord("A"))
# Out:
# 65

# %%
# While Loop 
# For Loop



i=2
while i<=5:
     if i==2:
         break
      
     
    

print("Outside Loop")

# Write a program to print   20 natural Number using loop
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 9
#       7 while i<=5:
#       8      if i==2:
# ----> 9           continue
#      10      else:
#      11           print(i)
#
# KeyboardInterrupt:

# %% [markdown]
# #### Write a python script  to print first 10 odd Number
# #### write a python script to print first N even natural Number
#
# #### Write a Python Script to print first 10 odd Natural Number in reverse order
#
# #### write a python Script to calculate sum of first N natural numbers

# %%
# Write a program to print Table of Given number
# Write a program to print N natural number

# %%
# An iterable object is something that contains a countable numbers of value
# You can traverse through all the values from beginning to the end

# In python an iterator is an object which implements the iterator protocal which consist of methods __iter__() and __next__()



# range
# list
# tuple
# str
# bytes
# bytearray
# set
# frozenset
# dict


# range is class
# range is immutable sequences
# range can contain only int type values
# range contains sequnces of integers with common diffrence (Arithmetic progression)

# %%
# r=range(beg,end,step)

# range(2,10,2)

# range(end) beg=0 step=1

# range(beg,end) step=1

for i in range(5,10):
    print(i)
# Out:
# 5
# 6
# 7
# 8
# 9

# %%
# write a program to print first n natural numbers

# %%
a = 2
print(type(a))
# Out:
# <class 'int'>

# %%
for ele in "GlobalIOT":
    print(ele,end=" ")
# Out:
# G l o b a l I O T

# %%
e  = range(10,1,-1)
for i in e:
    print(i,end=" ")

str = "GlobalIOT"
print(str)
# Out:
# 3 5 7 9 GlobalIOT

# %%
for i in range(2,5):
    print(i,end=" ")
# Out:
# 2 3 4

# %%
# 1 to 10 

for i  in range(10):
    if i%2==0:
        print(i)
# Out:
# 0
# 2
# 4
# 6
# 8

# %%
li1=["Suman",8,True]

li1 = [[1,2,3],[4,5,6],[6,5,8]]
li2 = [[6,7,3],[5,7,2],[6,3,8]]
# using for and While loop

print(li1+li2)
res = [[7,9,6],[9,12,8],[12,8,16]]
print(li1[1][2])


print(li1[-2])

print(li1[1],li1[-2])

for i in li1[0]:
    print(i)


# for ele in li1:
#     print(ele)
# Out:
# [[1, 2, 3], [4, 5, 6], [6, 5, 8], [6, 7, 3], [5, 7, 2], [6, 3, 8]]
# 6
# [4, 5, 6]
# [4, 5, 6] [4, 5, 6]
# 1
# 2
# 3

# %%
firstName = "Suman"
lastName   = "Bhandari"
print(firstName+lastName)
# Out:
# SumanBhandari

# %%
li2 = ["Sumna","Haryy","Thor"]
li2[2]="Loki"
print(li2)
# Out:
# ['Sumna', 'Haryy', 'Loki']

# %%
# 1
# 121
# 12321
# 1234321

for i in range(5):
    for j in range(i+1):
        print(j+1,end="")
    print()
# Out:
# 1
# 12
# 123
# 1234
# 12345
