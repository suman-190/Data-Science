# %%
import math_utils
print(math_utils.add(2, 3))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import math_utils
#       2 print(math_utils.add(2, 3))
#
# ModuleNotFoundError: No module named 'math_utils'
