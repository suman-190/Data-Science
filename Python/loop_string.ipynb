# %%
for i in range(1,10):
    if i ==5:
        break
    print(i)
# Out:
# 1
# 2
# 3
# 4

# %%
for i in range(1,10):
    if i ==5:
        continue
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 6
# 7
# 8
# 9

# %%
for i in range(1,10):
    pass

# %%
# In python Specifically, strings are a sequence of UniCode Character

s= 'Hello'
s1 = "Hello"
s2= '''hello'''
print(s2)
# Out:
# hello

# %%
# Indexing

s1 = 'DataBaseManagementSystem'

print(s1[-3])

# Slicing

print(s1[1:])
print(s1[:4])
print(s1[0:5])
print(s1[0:10:2])
# Out:
# t
# ataBaseManagementSystem
# Data
# DataB
# DtBsM

# %%
s= "GlobalIOT"
del s[1]
print(s)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 3
#       1 s= "GlobalIOT"
# ----> 3 del s[1]
#       4 print(s)
#
# TypeError: 'str' object doesn't support item deletion

# %%
print('Global'+'IOT')
print("Glibal"*5)
# Out:
# GlobalIOT
# GlibalGlibalGlibalGlibalGlibal

# %%
def is_even(num):
      
    '''This function will check the even numbers'''
    if num%2==0:
        return "Even"
    else:
        return "Odd"  
         

print(is_even.__doc__)
# Out:
# This function will check the even numbers

# %%
l1 = ["Apple","Banana","Mango"]

del l1[1]

print(l1)
# Out:
# ['Apple', 'Mango']

# %%
s1 = "String"

del s1[1]

print(s1[1])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 3
#       1 s1 = "String"
# ----> 3 del s1[1]
#       5 print(s1[1])
#
# TypeError: 'str' object doesn't support item deletion

# %%
for i in range(1,10):
    if i==5:
        break
    print(i)
print("OUTSIDE")
# Out:
# 1
# 2
# 3
# 4
# OUTSIDE

# %%
for i in range(1,10):
    if i==5:
        continue
    print(i)
print("OUTSIDE")
# Out:
# 1
# 2
# 3
# 4
# 6
# 7
# 8
# 9
# OUTSIDE

# %%
for i in range(1,10):
    pass

# %%
# Write a program to search element in List using function

li =  [10,30,32,48,56]

# %%
print("Global" +" " + "IOT")
print("Global" * 5)
# Out:
# Global IOT
# GlobalGlobalGlobalGlobalGlobal

# %%
s1 = "DataBaseManagementSystem"

count=0
for i in s1:
    if i=="S" or i=="s":
        count=count+1
        
print(count)

# print(s1[1:10:2])
# print(s1[2:])
# print(s1[:5])
# Out:
# 3

# %%
str1 = "DataBaseManagementSystem"

print(str1[::-2])



# step  = +ve beg=0
# step = -ve  beg=lastindex
# Out:
# mtyteeaaeaaa

# %%
s1 = "Data Base Management"

print(len(s1))

for i in s1:
    if i==" ":
        pass
# Out:
# 20
